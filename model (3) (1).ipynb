# %% [markdown]
# # Импорт библиотек

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from lightgbm import LGBMClassifier

from sklearn.metrics import (
    roc_auc_score, recall_score, confusion_matrix, roc_curve,
    precision_recall_curve, classification_report
)

# %%
def simple_clearing_train(df_train: pd.DataFrame, fill_percent_threshold=97, corr_percent_threshold=100, onlyfloat=False):
    df = df_train
    
    # Дроп столбцов, заполненных меньше, чем не fiil_percent_threshold %
    df = df.drop(columns=[col for col in df.columns
        if df[col].count() / len(df.index) < fill_percent_threshold / 100])
    
    
    # Замена None в категориальных данных на новый категориальный признак
    categorical_columns = [col for col in df.columns if str(df[col].dtype) == 'object']
    df[categorical_columns] = df[categorical_columns].fillna('CatNone')
    
    # Замена NaN в числовых данных на медианное значение
    float_columns = [col for col in df.columns if str(df[col].dtype) == 'float64']
    df[float_columns] = df[float_columns].fillna(df[float_columns].median())
    
    # Разбиение категории segment на пять бинарных столбцов
    dummies = pd.get_dummies(df,
        columns=['segment'])[[f'segment_{n}' for n in [0, 1, 2, 3, 'CatNone']]].astype(np.float64)
    segment_idx = df.columns.get_loc('segment')
    df = df.drop(columns=['segment'])
    for n in ['CatNone', 3, 2, 1, 0]:
        df.insert(segment_idx, f'segment_{n}', dummies[f'segment_{n}'])
        
    # Если интересуют только числовые данные
    if onlyfloat:
        float_columns = [col for col in df.columns if str(df[col].dtype) in ('float64', 'int32')]
        df = df[float_columns]
        
    # Дроп столбцов, кореллирующих с какими-либо другими более, чем на corr_percent_threshold %
    """
    if corr_percent_threshold < 100:
        float_columns = [col for col in df.columns if str(df[col].dtype) == 'float64']
        dff = df[float_columns]
        dff_corr = dff.corr()
        most_corellated_pairs = [
            (dff.columns[i], dff.columns[j], dff_corr[dff.columns[i]].loc[dff.columns[j]])
            for i in range(len(dff.columns))
            for j in range(i+1, len(dff.columns))
        ]
        most_corellated_pairs.sort(
            key=lambda col_pair: abs(col_pair[2]), reverse=True
        )
        most_corellated_pairs = pd.DataFrame(data=most_corellated_pairs,
            columns=['feature_1', 'feature_2', 'correllation'])
        mcp = most_corellated_pairs
        while mcp['correllation'].iloc[0] > (corr_percent_threshold / 100):
            c11 = (mcp['feature_1'].value_counts().loc[mcp['feature_1'].iloc[0]]
                if mcp['feature_1'].iloc[0] in mcp['feature_1'].value_counts().index else 0)
            c21 = (mcp['feature_2'].value_counts().loc[mcp['feature_1'].iloc[0]]
                if mcp['feature_1'].iloc[0] in mcp['feature_2'].value_counts().index else 0)
            c12 = (mcp['feature_1'].value_counts().loc[mcp['feature_2'].iloc[0]]
                if mcp['feature_2'].iloc[0] in mcp['feature_1'].value_counts().index else 0)
            c22 = (mcp['feature_2'].value_counts().loc[mcp['feature_2'].iloc[0]]
                if mcp['feature_2'].iloc[0] in mcp['feature_2'].value_counts().index else 0)
            excessive_feature = mcp['feature_1'].iloc[0] if c11 + c21 < c12 + c22 else mcp['feature_2'].iloc[0]
            df = df.drop(columns=[excessive_feature])
            dff = dff.drop(columns=[excessive_feature])
            dff_corr = dff_corr.drop(columns=[excessive_feature])
            dff_corr = dff_corr.drop(index=[excessive_feature])
            mcp = mcp.loc[(mcp['feature_1'] != excessive_feature) & (mcp['feature_2'] != excessive_feature)]
    """
    return df

def simple_clearing_test(df_test: pd.DataFrame, df_train_clean: pd.DataFrame):
    # Выбор только тех столбцов, которые были в трейне
    targets = ['target_1', 'target_2', 'total_target']

    # Разбиение категории segment на пять бинарных столбцов
    dummies = pd.get_dummies(df_test, columns=['segment'])
    if 'segment_CatNone' not in dummies.columns:
        dummies.insert(len(dummies.columns), 'segment_CatNone', 0.0)
    dummies = dummies[[f'segment_{n}' for n in [0, 1, 2, 3, 'CatNone']]].astype(np.float64)
    segment_idx = df_test.columns.get_loc('segment')
    df_test = df_test.drop(columns=['segment'])
    for n in ['CatNone', 3, 2, 1, 0]:
        df_test.insert(segment_idx, f'segment_{n}', dummies[f'segment_{n}'])
    
    df_train_clean_columns = [col for col in df_train_clean.columns if col not in targets]
    df_test = df_test[df_train_clean_columns]
    
    """
    # Замена None в категориальных данных на новый категориальный признак
    categorical_columns = [col for col in df_test.columns if str(df_test[col].dtype) == 'object']
    df_test[categorical_columns] = df_test[categorical_columns].fillna('CatNone')
    # Замена NaN в числовых данных на медианное значение
    float_columns = [col for col in df_test.columns if str(df_test[col].dtype) == 'float64']
    df_test[float_columns] = df_test[float_columns].fillna(df_test[float_columns].median())
    """
    return df_test

# %%
file_path = '../test.parquet'
test_data = pd.read_parquet(file_path, engine='pyarrow')

file_path = '../train.parquet'
train_data = pd.read_parquet(file_path, engine='pyarrow')

train_data = simple_clearing_train(train_data, 80, 100, False)

categorical_columns = [col for col in train_data.columns if str(train_data[col].dtype) == 'object']

train_data = train_data.drop(columns=categorical_columns)

train_data.isnull().any().sum()
# Out:
# 0

# %%
test_data = simple_clearing_test(test_data, train_data)

# %%
def clear_outliers_column(df1, column, a_max, b_min):
    a_max = df1[column].max() * a_max
    b_min = df1[column].min() * b_min
    df1 = df1.drop(df1[df1[column] < b_min].index)
    df1 = df1.drop(df1[df1[column] > a_max].index)
    return df1


def clear_outliers_all(df1):
    try:
    # rko_start_months
        df1 = clear_outliers_column(df1, 'rko_start_months', 0.6, 0.9)
        print(df1.size)
    except:
        print('rko_start_months')

    try:
        # balance_amt_avg
        df1 = clear_outliers_column(df1, 'balance_amt_avg', 0.2, 1)
    except:
        print('balance_amt_avg')

    try:
        # balance_amt_max
        df1 = clear_outliers_column(df1, 'balance_amt_max', 0.05, 1)
    except:
        print('balance_amt_max')

    try:
        # balance_amt_min
        df1 = clear_outliers_column(df1, 'balance_amt_min', 0.25, 1)
    except:
        print('balance_amt_min')

    try:
        # balance_amt_day_avg
        df1 = clear_outliers_column(df1, 'balance_amt_day_avg', 0.5, 1)
    except:
        print('balance_amt_day_avg')

    try:
        # ogrn_days_end_month
        df1 = clear_outliers_column(df1, 'ogrn_days_end_month', 0.9, 0.9)
    except:
        print('ogrn_days_end_month')

    try:
        # ogrn_days_end_quarter
        df1 = clear_outliers_column(df1, 'ogrn_days_end_quarter', 0.9, 0.9)
    except:
        print('ogrn_days_end_quarter')

    try:
        # ogrn_exist_months
        df1 = clear_outliers_column(df1, 'ogrn_exist_months', 0.9, 0.9)
    except:
        print('ogrn_exist_months')

    try:
        # sum_of_paym_2m
        df1 = clear_outliers_column(df1, 'sum_of_paym_2m', 0.2, 1)
    except:
        print('sum_of_paym_2m')

    try:
        # sum_of_paym_6m
        df1 = clear_outliers_column(df1, 'sum_of_paym_6m', 0.15, 1)
    except:
        print('sum_of_paym_6m')

    try:
        # sum_of_paym_1y
        df1 = clear_outliers_column(df1, 'sum_of_paym_1y', 0.3, 1)
    except:
        print('sum_of_paym_1y')

    try:
        # sum_a_oper_1m
        df1 = clear_outliers_column(df1, 'sum_a_oper_1m', 0.25, 1)
    except:
        print('sum_a_oper_1m')

    try:
        # cnt_a_oper_1m
        df1 = clear_outliers_column(df1, 'cnt_a_oper_1m', 0.5, 1)
    except:
        print('cnt_a_oper_1m')

    try:
        # sum_b_oper_1m
        df1 = clear_outliers_column(df1, 'sum_b_oper_1m', 0.25, 1)
    except:
        print('sum_b_oper_1m')

    try:
        # cnt_b_oper_1m
        df1 = clear_outliers_column(df1, 'cnt_b_oper_1m', 0.1, 1)
    except:
        print('cnt_b_oper_1m')

    try:
        # sum_c_oper_1m
        df1 = clear_outliers_column(df1, 'sum_c_oper_1m', 0.25, 1)
    except:
        print('sum_c_oper_1m')

    try:
        # cnt_c_oper_1m
        df1 = clear_outliers_column(df1, 'cnt_c_oper_1m', 0.25, 1)
    except:
        print('cnt_c_oper_1m')

    try:
        # sum_deb_d_oper_1m
        df1 = clear_outliers_column(df1, 'sum_deb_d_oper_1m', 0.2, 0.9)
    except:
        print('sum_deb_d_oper_1m')

    try:
        # cnt_deb_d_oper_1m
        df1 = clear_outliers_column(df1, 'cnt_deb_d_oper_1m', 0.2, 0.9)
    except:
        print('cnt_deb_d_oper_1m')

    try:
        # sum_cred_d_oper_1m
        df1 = clear_outliers_column(df1, 'sum_cred_d_oper_1m', 0.2, 0.9)
    except:
        print('sum_cred_d_oper_1m')

    try:
        # cnt_cred_d_oper_1m
        df1 = clear_outliers_column(df1, 'cnt_cred_d_oper_1m', 0.2, 1)
    except:
        print('cnt_cred_d_oper_1m')

    try:
        # sum_deb_e_oper_1m
        df1 = clear_outliers_column(df1, 'sum_deb_e_oper_1m', 0.2, 1)
    except:
        print('sum_deb_e_oper_1m')

    try:
        # cnt_deb_e_oper_1m
        df1 = clear_outliers_column(df1, 'cnt_deb_e_oper_1m', 0.4, 1)
    except:
        print('cnt_deb_e_oper_1m')

    try:
        # sum_cred_e_oper_1m
        df1 = clear_outliers_column(df1, 'sum_cred_e_oper_1m', 0.3, 1)
    except:
        print('sum_cred_e_oper_1m')

    try:
        # cnt_cred_e_oper_1m
        df1 = clear_outliers_column(df1, 'cnt_cred_e_oper_1m', 0.1, 1)
    except:
        print('cnt_cred_e_oper_1m')

    try:
        # cnt_days_cred_e_oper_1m
        df1 = clear_outliers_column(df1, 'cnt_days_cred_e_oper_1m', 0.95, 0.9)
    except:
        print('cnt_days_cred_e_oper_1m')

    try:
        # sum_deb_f_oper_1m
        df1 = clear_outliers_column(df1, 'sum_deb_f_oper_1m', 0.2, 1)
    except:
        print('sum_deb_f_oper_1m')

    try:
        # cnt_deb_f_oper_1m
        df1 = clear_outliers_column(df1, 'cnt_deb_f_oper_1m', 0.2, 1)
    except:
        print('cnt_deb_f_oper_1m')

    try:
        # sum_cred_f_oper_1m
        df1 = clear_outliers_column(df1, 'sum_cred_f_oper_1m', 0.3, 1)
    except:
        print('sum_cred_f_oper_1m')

    try:
        # cnt_cred_f_oper_1m
        df1 = clear_outliers_column(df1, 'cnt_cred_f_oper_1m', 0.5, 1)
    except:
        print('cnt_cred_f_oper_1m')

    try:
        # cnt_days_cred_f_oper_1m
        df1 = clear_outliers_column(df1, 'cnt_days_cred_f_oper_1m', 0.8, 1)
    except:
        print('cnt_days_cred_f_oper_1m')

    try:
        # sum_deb_g_oper_1m
        df1 = clear_outliers_column(df1, 'sum_deb_g_oper_1m', 0.3, 1)
    except:
        print('sum_deb_g_oper_1m')

    try:
        # cnt_deb_g_oper_1m
        df1 = clear_outliers_column(df1, 'cnt_deb_g_oper_1m', 0.4, 1)
    except:
        print('cnt_deb_g_oper_1m')

    try:
        # sum_cred_g_oper_1m
        df1 = clear_outliers_column(df1, 'sum_cred_g_oper_1m', 0.4, 0.8)
    except:
        print('sum_cred_g_oper_1m')

    try:
        # cnt_cred_g_oper_1m
        df1 = clear_outliers_column(df1, 'cnt_cred_g_oper_1m', 0.4, 1)
    except:
        print('cnt_cred_g_oper_1m')

    try:
        # cnt_days_cred_g_oper_1m
        df1 = clear_outliers_column(df1, 'cnt_days_cred_g_oper_1m', 0.7, 0.7)
    except:
        print('cnt_days_cred_g_oper_1m')

    try:
        # cnt_deb_h_oper_1m
        df1 = clear_outliers_column(df1, 'cnt_deb_h_oper_1m', 0.3, 1)
    except:
        print('cnt_deb_h_oper_1m')

    try:
        # sum_cred_h_oper_1m
        df1 = clear_outliers_column(df1, 'sum_cred_h_oper_1m', 0.3, 1)
    except:
        print('sum_cred_h_oper_1m')

    try:
        # cnt_cred_h_oper_1m
        df1 = clear_outliers_column(df1, 'cnt_cred_h_oper_1m', 0.3, 1)
    except:
        print('cnt_cred_h_oper_1m')

    try:
        # sum_a_oper_3m
        df1 = clear_outliers_column(df1, 'sum_a_oper_3m', 0.8, 1)
    except:
        print('sum_a_oper_3m')

    try:
        # cnt_a_oper_3m
        df1 = clear_outliers_column(df1, 'cnt_a_oper_3m', 0.3, 0.7)
    except:
        print('cnt_a_oper_3m')

    try:
        # sum_b_oper_3m
        df1 = clear_outliers_column(df1, 'sum_b_oper_3m', 0.3, 1)
    except:
        print('sum_b_oper_3m')

    try:
        # cnt_b_oper_3m
        df1 = clear_outliers_column(df1, 'cnt_b_oper_3m', 0.8, 1)
    except:
        print('cnt_b_oper_3m')

    try:
        # sum_c_oper_3m
        df1 = clear_outliers_column(df1, 'sum_c_oper_3m', 0.3, 0.7)
    except:
        print('sum_c_oper_3m')

    try:
        # cnt_c_oper_3m
        df1 = clear_outliers_column(df1, 'cnt_c_oper_3m', 0.3, 0.7)
    except:
        print('cnt_c_oper_3m')

    try:
        # sum_deb_d_oper_3m
        df1 = clear_outliers_column(df1, 'sum_deb_d_oper_3m', 0.3, 1)
    except:
        print('sum_deb_d_oper_3m')

    try:
        # cnt_deb_d_oper_3m
        df1 = clear_outliers_column(df1, 'cnt_deb_d_oper_3m', 0.3, 1)
    except:
        print('cnt_deb_d_oper_3m')

    try:
        # sum_cred_d_oper_3m
        df1 = clear_outliers_column(df1, 'sum_cred_d_oper_3m', 0.2, 0.5)
    except:
        print('sum_cred_d_oper_3m')

    try:
        # cnt_cred_d_oper_3m
        df1 = clear_outliers_column(df1, 'cnt_cred_d_oper_3m', 0.3, 1)
    except:
        print('cnt_cred_d_oper_3m')

    try:
        # sum_deb_e_oper_3m
        df1 = clear_outliers_column(df1, 'sum_deb_e_oper_3m', 0.2, 1)
    except:
        print('sum_deb_e_oper_3m')

    try:
        # cnt_deb_e_oper_3m
        df1 = clear_outliers_column(df1, 'cnt_deb_e_oper_3m', 0.6, 1)
    except:
        print('cnt_deb_e_oper_3m')

    try:
        # cnt_days_deb_e_oper_3m
        df1 = clear_outliers_column(df1, 'cnt_deb_e_oper_3m', 1, 1)
    except:
        print('cnt_days_deb_e_oper_3m')

    try:
        # sum_cred_e_oper_3m
        df1 = clear_outliers_column(df1, 'sum_cred_e_oper_3m', 0.3, 1)
    except:
        print('sum_cred_e_oper_3m')

    try:
        # cnt_cred_e_oper_3m
        df1 = clear_outliers_column(df1, 'cnt_cred_e_oper_3m', 0.3, 0.7)
    except:
        print('cnt_cred_e_oper_3m')

    try:
        # cnt_days_cred_e_oper_3m
        df1 = clear_outliers_column(df1, 'cnt_days_cred_e_oper_3m', 0.9, 0.9)
    except:
        print('cnt_days_cred_e_oper_3m')

    try:
        # sum_deb_f_oper_3m
        df1 = clear_outliers_column(df1, 'sum_deb_f_oper_3m', 0.3, 0.8)
    except:
        print('sum_deb_f_oper_3m')

    try:
        # cnt_deb_f_oper_3m
        df1 = clear_outliers_column(df1, 'cnt_deb_f_oper_3m', 0.3, 1)
    except:
        print('cnt_deb_f_oper_3m')

    try:
        # sum_cred_f_oper_3m
        df1 = clear_outliers_column(df1, 'sum_cred_f_oper_3m', 0.3, 0.7)
    except:
        print('sum_cred_f_oper_3m')

    try:
        # cnt_cred_f_oper_3m
        df1 = clear_outliers_column(df1, 'cnt_cred_f_oper_3m', 0.6, 0.8)
    except:
        print('cnt_cred_f_oper_3m')

    try:
        # cnt_days_cred_f_oper_3m
        df1 = clear_outliers_column(df1, 'cnt_days_cred_f_oper_3m', 0.8, 1)
    except:
        print('cnt_days_cred_f_oper_3m')

    try:
        # sum_deb_g_oper_3m
        df1 = clear_outliers_column(df1, 'sum_deb_g_oper_3m', 0.3, 1)
    except:
        print('sum_deb_g_oper_3m')

    try:
        # cnt_deb_g_oper_3m
        df1 = clear_outliers_column(df1, 'cnt_deb_g_oper_3m', 0.3, 0.8)
    except:
        print('cnt_deb_g_oper_3m')

    try:
        # sum_cred_g_oper_3m
        df1 = clear_outliers_column(df1, 'sum_cred_g_oper_3m', 0.3, 0.8)
    except:
        print('sum_cred_g_oper_3m')

    try:
        # cnt_cred_g_oper_3m
        df1 = clear_outliers_column(df1, 'cnt_cred_g_oper_3m', 0.3, 1)
    except:
        print('cnt_cred_g_oper_3m')

    try:
        # sum_deb_h_oper_3m
        df1 = clear_outliers_column(df1, 'sum_deb_h_oper_3m', 0.3, 0.8)
    except:
        print('sum_deb_h_oper_3m')

    try:
        # cnt_deb_h_oper_3m
        df1 = clear_outliers_column(df1, 'cnt_deb_h_oper_3m', 0.3, 1)
    except:
        print('cnt_deb_h_oper_3m')

    try:
        # cnt_days_deb_h_oper_3m
        df1 = clear_outliers_column(df1, 'cnt_days_deb_h_oper_3m', 0.8, 0.8)
    except:
        print('cnt_days_deb_h_oper_3m')

    try:
        # sum_cred_h_oper_3m
        df1 = clear_outliers_column(df1, 'sum_cred_h_oper_3m', 0.3, 0.8)
    except:
        print('sum_cred_h_oper_3m')

    try:
        # cnt_cred_h_oper_3m
        df1 = clear_outliers_column(df1, 'cnt_cred_h_oper_3m', 0.3, 0.8)
    except:
        print('cnt_cred_h_oper_3m')

    try:
        # cnt_days_cred_h_oper_3m
        df1 = clear_outliers_column(df1, 'cnt_days_cred_h_oper_3m', 0.9, 1)
    except:
        print('cnt_days_cred_h_oper_3m')

    return df1

# %%
train_data = clear_outliers_all(train_data)
# Out:
# 26676148

# %%
# Скопируйте train_data в новый DataFrame, чтобы не изменить оригинальные данные
normalized_train_data = train_data.copy()
normalized_train_data = normalized_train_data.drop(columns=['total_target'])
# Пройдитесь по всем численным колонкам (не включая 'total_target')
for column in normalized_train_data.columns:
    if column != 'total_target' and pd.api.types.is_numeric_dtype(normalized_train_data[column]):
        # Найдите минимальное значение в колонке
        min_value = normalized_train_data[column].min()
        
        # Вычислите разницу между каждым значением в колонке и минимальным значением
        normalized_train_data[column] = normalized_train_data[column] - min_value
        
normalized_train_data['total_target'] = train_data['total_target']

normalized_train_data
# Out:
#             id  rko_start_months  balance_amt_avg  balance_amt_max  \
# 0            0          0.885215         2.608914         0.028533
# 1            1          1.021757         2.555110         0.027253
# 2            2          3.976618         2.834930         0.869540
# 3            3          1.684940         1.288050         0.014748
# 4            4          0.660657         1.893093         0.039220
# ...        ...               ...              ...              ...
# 299994  299994          2.265337         2.654107         0.026899
# 299995  299995          2.304841         2.431620         0.561383
# 299996  299996          1.586014         1.856317         0.016154
# 299997  299997          4.217058         2.388721         0.155310
# 299999  299999          1.521990         2.073360         0.009276
#
#         balance_amt_min  balance_amt_day_avg  ogrn_days_end_month  \
# 0              1.599135             1.964366             4.769726
# 1              2.104713             1.382803             1.944955
# 2              2.372285             2.407360             4.464299
# 3              1.578623             1.374037             4.348618
# 4              1.714327             1.706443             2.373471
# ...                 ...                  ...                  ...
# 299994         1.549070             2.244852             2.825727
# 299995         1.798068             1.403035             3.790300
# 299996         1.353827             1.505075             3.214933
# 299997         2.237694             1.845013             2.312193
# 299999         1.265122             1.583219             4.106212
#
#         ogrn_days_end_quarter  ft_registration_date  ogrn_exist_months  ...  \
# 0                    3.187807              0.191454           1.270947  ...
# 1                    3.481021              0.990446           1.650861  ...
# 2                    4.639854              1.516399           2.415288  ...
# 3                    1.673837              2.622696           3.688806  ...
# 4                    2.659801              0.050583           0.843449  ...
# ...                       ...                   ...                ...  ...
# 299994               1.201371              0.465580           1.601047  ...
# 299995               4.433043              0.470475           1.227503  ...
# 299996               2.613005              1.559911           2.562776  ...
# 299997               3.437996              1.291224           2.797055  ...
# 299999               3.790403              0.188734           1.203260  ...
#
#         cnt_days_cred_g_oper_3m  sum_deb_h_oper_3m  cnt_deb_h_oper_3m  \
# 0                      0.676003           1.379569           0.526753
# 1                      0.135201           0.810263           0.000000
# 2                      0.000000           2.093610           2.858121
# 3                      0.000000           1.457330           0.097547
# 4                      0.000000           1.643605           0.029264
# ...                         ...                ...                ...
# 299994                 0.000000           1.374469           0.165830
# 299995                 0.405602           1.737785           0.663318
# 299996                 0.000000           1.196326           0.000000
# 299997                 0.000000           1.600238           0.000000
# 299999                 0.000000           1.207447           0.048773
#
#         cnt_days_deb_h_oper_3m  sum_cred_h_oper_3m  cnt_cred_h_oper_3m  \
# 0                     2.995209            2.230304            2.277450
# 1                     0.717864            1.455501            1.319244
# 2                     4.871882            1.616221            1.486536
# 3                     2.083025            1.154642            1.245631
# 4                     1.325479            1.019492            1.445058
# ...                        ...                 ...                 ...
# 299994                1.806185            2.334978            0.975502
# 299995                3.389562            2.301460            1.224505
# 299996                1.381484            1.529652            1.689317
# 299997                1.085434            1.467419            1.412099
# 299999                1.585098            2.198728            1.252581
#
#         cnt_days_cred_h_oper_3m  target_1  target_2  total_target
# 0                      2.505676         0         0             0
# 1                      0.078302         0         0             0
# 2                      1.174536         0         0             0
# 3                      0.000000         0         0             0
# 4                      0.234907         0         0             0
# ...                         ...       ...       ...           ...
# 299994                 0.000000         0         0             0
# 299995                 0.548117         0         0             0
# 299996                 0.000000         0         0             0
# 299997                 0.548117         0         0             0
# 299999                 0.548117         0         0             0
#
# [270269 rows x 89 columns]

# %%
# Создайте список типов операций (e, f, g, h)
operation_types = ['e', 'f', 'g', 'h']

# Создайте пустой DataFrame для хранения результатов
result_df = pd.DataFrame()

# Переберите каждый тип операции и каждый суффикс (_1m, _3m)
for operation_type in operation_types:
    for suffix in ['_1m', '_3m']:
        # Создайте список столбцов, которые содержат информацию о данном типе операции и суффиксе
        columns_to_process = [
            f'sum_deb_{operation_type}_oper{suffix}',
            f'cnt_deb_{operation_type}_oper{suffix}',
            f'cnt_days_deb_{operation_type}_oper{suffix}'
        ]
        
        # Вычислите отношение cnt_deb к cnt_days_deb для данного типа операции и суффикса
        result_df[f'ratio_{operation_type}{suffix}'] = normalized_train_data[columns_to_process[1]] / normalized_train_data[columns_to_process[2]]
     
    
# Вычислите разницу между значениями для суффиксов _3m и _1m и создайте новый столбец для каждой категории ratio_
for operation_type in operation_types:
    result_df[f'diff_{operation_type}'] = result_df[f'ratio_{operation_type}_3m'] - result_df[f'ratio_{operation_type}_1m']

# Скопируйте столбец 'total_target' из train_data в result_df
result_df['total_target'] = train_data['total_target']


result_df
# Out:
#         ratio_e_1m  ratio_e_3m  ratio_f_1m  ratio_f_3m  ratio_g_1m  \
# 0         0.090440    0.042598         NaN    0.013064    0.362313
# 1         0.031654    0.004422    0.013045    0.013064         NaN
# 2         0.172551    0.120274         NaN    0.137175    0.672866
# 3         0.030147    0.025995         NaN         NaN    0.362313
# 4         0.036741    0.014632    0.015654    0.015440         NaN
# ...            ...         ...         ...         ...         ...
# 299994    0.039385    0.028102    0.015654    0.015864    0.398544
# 299995    0.107398    0.048709         NaN         NaN    0.543469
# 299996    0.033915    0.006174         NaN         NaN         NaN
# 299997    0.035530    0.011638    0.021741    0.020903    0.483083
# 299999    0.041452    0.024040    0.014349    0.013548    0.422698
#
#         ratio_g_3m  ratio_h_1m  ratio_h_3m    diff_e    diff_f    diff_g  \
# 0         9.579392    0.334450    0.175865 -0.047842       NaN  9.217080
# 1              inf         NaN    0.000000 -0.027232  0.000020       NaN
# 2         1.623990    0.959644    0.586656 -0.052277       NaN  0.951123
# 3         0.877879    0.152023    0.046829 -0.004152       NaN  0.515566
# 4              inf    0.152023    0.022078 -0.022109 -0.000214       NaN
# ...            ...         ...         ...       ...       ...       ...
# 299994    0.687536    0.182427    0.091812 -0.011283  0.000210  0.288992
# 299995    6.087186    0.483709    0.195694 -0.058688       NaN  5.543717
# 299996         inf         NaN    0.000000 -0.027741       NaN       NaN
# 299997    4.720069         NaN    0.000000 -0.023892 -0.000838  4.236985
# 299999    1.693201    0.152023    0.030770 -0.017412 -0.000801  1.270503
#
#           diff_h  total_target
# 0      -0.158585             0
# 1            NaN             0
# 2      -0.372987             0
# 3      -0.105193             0
# 4      -0.129945             0
# ...          ...           ...
# 299994 -0.090615             0
# 299995 -0.288014             0
# 299996       NaN             0
# 299997       NaN             0
# 299999 -0.121253             0
#
# [270269 rows x 13 columns]

# %% [markdown]
# Метрики активности и динамики активности по разным категориям операций

# %%
import dataframe_image as dfi

corlist = ['rko_start_months', 'cnt_days_deb_e_oper_1m', 'cnt_cred_e_oper_1m', 'cnt_days_cred_e_oper_1m', 'cnt_days_deb_f_oper_1m', 'cnt_days_deb_h_oper_1m', 'cnt_days_cred_h_oper_1m', 'sum_deb_e_oper_3m', 'cnt_deb_e_oper_3m', 'cnt_days_deb_e_oper_3m', 'sum_cred_e_oper_3m', 'cnt_days_cred_e_oper_3m', 'cnt_days_deb_f_oper_3m', 'cnt_deb_h_oper_3m', 'cnt_days_deb_h_oper_3m', 'cnt_days_cred_h_oper_3m']

corr = result_df.corr().round(3)
df_styled = corr.style.background_gradient(cmap='coolwarm')
dfi.export(df_styled, 'df_styled.svg')
df_styled
# Out:
# <style type="text/css">
# #T_c9e27_row0_col0, #T_c9e27_row1_col1, #T_c9e27_row2_col2, #T_c9e27_row3_col3, #T_c9e27_row4_col4, #T_c9e27_row5_col5, #T_c9e27_row5_col10, #T_c9e27_row6_col6, #T_c9e27_row7_col7, #T_c9e27_row8_col8, #T_c9e27_row9_col9, #T_c9e27_row10_col5, #T_c9e27_row10_col10, #T_c9e27_row11_col11, #T_c9e27_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c9e27_row0_col1 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_c9e27_row0_col2 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_c9e27_row0_col3 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_c9e27_row0_col4 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_c9e27_row0_col5, #T_c9e27_row4_col10, #T_c9e27_row8_col12 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_c9e27_row0_col6 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_c9e27_row0_col7, #T_c9e27_row6_col1 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_c9e27_row0_col8, #T_c9e27_row1_col5, #T_c9e27_row1_col10, #T_c9e27_row1_col12, #T_c9e27_row2_col9, #T_c9e27_row6_col11, #T_c9e27_row7_col12, #T_c9e27_row8_col0, #T_c9e27_row8_col1, #T_c9e27_row8_col3, #T_c9e27_row8_col4, #T_c9e27_row9_col2, #T_c9e27_row11_col6, #T_c9e27_row11_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c9e27_row0_col9, #T_c9e27_row10_col12 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_c9e27_row0_col10, #T_c9e27_row6_col5, #T_c9e27_row6_col10, #T_c9e27_row8_col5 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_c9e27_row0_col11 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_c9e27_row0_col12, #T_c9e27_row7_col5, #T_c9e27_row7_col10 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_c9e27_row1_col0 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_c9e27_row1_col2 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_c9e27_row1_col3 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_c9e27_row1_col4, #T_c9e27_row4_col1, #T_c9e27_row9_col11 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_c9e27_row1_col6 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_c9e27_row1_col7 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_c9e27_row1_col8, #T_c9e27_row4_col8, #T_c9e27_row4_col9, #T_c9e27_row6_col9 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_c9e27_row1_col9, #T_c9e27_row10_col2 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_c9e27_row1_col11, #T_c9e27_row10_col11 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_c9e27_row2_col0 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_c9e27_row2_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_c9e27_row2_col3 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_c9e27_row2_col4, #T_c9e27_row7_col8 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_c9e27_row2_col5, #T_c9e27_row5_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_c9e27_row2_col6 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_c9e27_row2_col7 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_c9e27_row2_col8, #T_c9e27_row8_col6, #T_c9e27_row9_col1, #T_c9e27_row10_col3 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_c9e27_row2_col10 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_c9e27_row2_col11 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_c9e27_row2_col12, #T_c9e27_row4_col12 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_c9e27_row3_col0, #T_c9e27_row7_col1 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_c9e27_row3_col1 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_c9e27_row3_col2 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_c9e27_row3_col4 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_c9e27_row3_col5, #T_c9e27_row11_col1 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_c9e27_row3_col6 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_c9e27_row3_col7 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_c9e27_row3_col8, #T_c9e27_row3_col9 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_c9e27_row3_col10 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_c9e27_row3_col11 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_c9e27_row3_col12 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_c9e27_row4_col0 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_c9e27_row4_col2, #T_c9e27_row9_col0 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_c9e27_row4_col3, #T_c9e27_row7_col11 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_c9e27_row4_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_c9e27_row4_col6, #T_c9e27_row8_col11, #T_c9e27_row11_col8 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_c9e27_row4_col7, #T_c9e27_row7_col3, #T_c9e27_row9_col6 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_c9e27_row4_col11 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_c9e27_row5_col0, #T_c9e27_row10_col0 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_c9e27_row5_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_c9e27_row5_col2, #T_c9e27_row12_col9 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_c9e27_row5_col3 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_c9e27_row5_col6 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_c9e27_row5_col7 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_c9e27_row5_col8, #T_c9e27_row8_col9 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_c9e27_row5_col9, #T_c9e27_row11_col9 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_c9e27_row5_col11, #T_c9e27_row6_col2, #T_c9e27_row12_col6 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_c9e27_row5_col12 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_c9e27_row6_col0 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_c9e27_row6_col3 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_c9e27_row6_col4 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_c9e27_row6_col7 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_c9e27_row6_col8, #T_c9e27_row11_col2 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_c9e27_row6_col12, #T_c9e27_row10_col1 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_c9e27_row7_col0 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_c9e27_row7_col2 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_c9e27_row7_col4 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_c9e27_row7_col6 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_c9e27_row7_col9, #T_c9e27_row12_col2 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_c9e27_row8_col2 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_c9e27_row8_col7 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_c9e27_row8_col10 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_c9e27_row9_col3 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_c9e27_row9_col4, #T_c9e27_row9_col10 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_c9e27_row9_col5 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_c9e27_row9_col7, #T_c9e27_row11_col5 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_c9e27_row9_col8 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_c9e27_row9_col12 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_c9e27_row10_col4, #T_c9e27_row12_col1 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_c9e27_row10_col6 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_c9e27_row10_col7 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_c9e27_row10_col8 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_c9e27_row10_col9 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_c9e27_row11_col0 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_c9e27_row11_col3 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_c9e27_row11_col4 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_c9e27_row11_col10 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_c9e27_row11_col12 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_c9e27_row12_col0 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_c9e27_row12_col3 {
#   background-color: #80a3fa;
#   color: #f1f1f1

# %%
train_data['cnt_days_cred_e_oper_1m'].corr(train_data['cnt_cred_e_oper_1m'])
# Out:
# 0.5983431601601641

# %%
corr = train_data.corr().round(3)

corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_d29b7_row0_col0, #T_d29b7_row1_col1, #T_d29b7_row2_col2, #T_d29b7_row3_col3, #T_d29b7_row4_col4, #T_d29b7_row5_col5, #T_d29b7_row6_col6, #T_d29b7_row7_col7, #T_d29b7_row8_col8, #T_d29b7_row9_col9, #T_d29b7_row10_col10, #T_d29b7_row11_col11, #T_d29b7_row12_col12, #T_d29b7_row13_col13, #T_d29b7_row14_col14, #T_d29b7_row15_col15, #T_d29b7_row16_col16, #T_d29b7_row17_col17, #T_d29b7_row18_col18, #T_d29b7_row19_col19, #T_d29b7_row20_col20, #T_d29b7_row21_col21, #T_d29b7_row22_col22, #T_d29b7_row23_col23, #T_d29b7_row24_col24, #T_d29b7_row25_col25, #T_d29b7_row26_col26, #T_d29b7_row27_col27, #T_d29b7_row28_col28, #T_d29b7_row29_col29, #T_d29b7_row30_col30, #T_d29b7_row31_col31, #T_d29b7_row32_col32, #T_d29b7_row33_col33, #T_d29b7_row34_col34, #T_d29b7_row35_col35, #T_d29b7_row36_col36, #T_d29b7_row37_col37, #T_d29b7_row38_col38, #T_d29b7_row39_col39, #T_d29b7_row40_col40, #T_d29b7_row41_col41, #T_d29b7_row42_col42, #T_d29b7_row43_col43, #T_d29b7_row44_col44, #T_d29b7_row45_col45, #T_d29b7_row46_col46, #T_d29b7_row47_col47, #T_d29b7_row48_col48, #T_d29b7_row49_col49, #T_d29b7_row50_col50, #T_d29b7_row51_col51, #T_d29b7_row52_col52, #T_d29b7_row53_col53, #T_d29b7_row54_col54, #T_d29b7_row55_col55, #T_d29b7_row56_col56, #T_d29b7_row57_col57, #T_d29b7_row58_col58, #T_d29b7_row59_col59, #T_d29b7_row60_col60, #T_d29b7_row61_col61, #T_d29b7_row62_col62, #T_d29b7_row63_col63, #T_d29b7_row64_col64, #T_d29b7_row65_col65, #T_d29b7_row66_col66, #T_d29b7_row67_col67, #T_d29b7_row68_col68, #T_d29b7_row69_col69, #T_d29b7_row70_col70, #T_d29b7_row71_col71, #T_d29b7_row72_col72, #T_d29b7_row73_col73, #T_d29b7_row74_col74, #T_d29b7_row75_col75, #T_d29b7_row76_col76, #T_d29b7_row77_col77, #T_d29b7_row78_col78, #T_d29b7_row79_col79, #T_d29b7_row80_col80, #T_d29b7_row81_col81, #T_d29b7_row82_col82, #T_d29b7_row83_col83, #T_d29b7_row84_col84, #T_d29b7_row85_col85, #T_d29b7_row86_col86, #T_d29b7_row87_col87, #T_d29b7_row88_col88 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d29b7_row0_col1, #T_d29b7_row0_col31, #T_d29b7_row2_col50, #T_d29b7_row3_col68, #T_d29b7_row5_col64, #T_d29b7_row6_col48, #T_d29b7_row7_col28, #T_d29b7_row7_col48, #T_d29b7_row14_col48, #T_d29b7_row15_col70, #T_d29b7_row16_col69, #T_d29b7_row18_col33, #T_d29b7_row22_col1, #T_d29b7_row23_col41, #T_d29b7_row23_col52, #T_d29b7_row25_col41, #T_d29b7_row27_col44, #T_d29b7_row27_col45, #T_d29b7_row29_col45, #T_d29b7_row33_col1, #T_d29b7_row33_col49, #T_d29b7_row36_col16, #T_d29b7_row37_col8, #T_d29b7_row40_col44, #T_d29b7_row40_col78, #T_d29b7_row41_col8, #T_d29b7_row42_col8, #T_d29b7_row42_col59, #T_d29b7_row43_col8, #T_d29b7_row46_col64, #T_d29b7_row49_col8, #T_d29b7_row52_col23, #T_d29b7_row53_col51, #T_d29b7_row55_col17, #T_d29b7_row57_col42, #T_d29b7_row58_col10, #T_d29b7_row59_col41, #T_d29b7_row61_col45, #T_d29b7_row63_col19, #T_d29b7_row63_col34, #T_d29b7_row63_col45, #T_d29b7_row66_col9, #T_d29b7_row66_col51, #T_d29b7_row68_col8, #T_d29b7_row68_col33, #T_d29b7_row68_col67, #T_d29b7_row69_col9, #T_d29b7_row70_col84, #T_d29b7_row71_col8, #T_d29b7_row71_col17, #T_d29b7_row72_col1, #T_d29b7_row72_col8, #T_d29b7_row72_col48, #T_d29b7_row73_col3, #T_d29b7_row73_col17, #T_d29b7_row74_col55, #T_d29b7_row74_col80, #T_d29b7_row75_col9, #T_d29b7_row75_col84, #T_d29b7_row76_col16, #T_d29b7_row77_col8, #T_d29b7_row77_col47, #T_d29b7_row79_col58, #T_d29b7_row80_col40, #T_d29b7_row81_col35, #T_d29b7_row83_col8, #T_d29b7_row84_col10, #T_d29b7_row85_col83, #T_d29b7_row87_col62 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_d29b7_row0_col2, #T_d29b7_row0_col34, #T_d29b7_row0_col36, #T_d29b7_row0_col45, #T_d29b7_row0_col68, #T_d29b7_row0_col70, #T_d29b7_row1_col46, #T_d29b7_row2_col75, #T_d29b7_row3_col76, #T_d29b7_row4_col42, #T_d29b7_row4_col75, #T_d29b7_row5_col22, #T_d29b7_row6_col2, #T_d29b7_row6_col34, #T_d29b7_row6_col45, #T_d29b7_row6_col68, #T_d29b7_row6_col70, #T_d29b7_row6_col78, #T_d29b7_row7_col2, #T_d29b7_row7_col34, #T_d29b7_row7_col45, #T_d29b7_row7_col68, #T_d29b7_row8_col46, #T_d29b7_row9_col46, #T_d29b7_row9_col88, #T_d29b7_row11_col69, #T_d29b7_row12_col23, #T_d29b7_row12_col24, #T_d29b7_row12_col60, #T_d29b7_row12_col61, #T_d29b7_row13_col20, #T_d29b7_row14_col34, #T_d29b7_row14_col45, #T_d29b7_row14_col70, #T_d29b7_row14_col78, #T_d29b7_row15_col55, #T_d29b7_row16_col26, #T_d29b7_row17_col18, #T_d29b7_row17_col20, #T_d29b7_row17_col22, #T_d29b7_row17_col26, #T_d29b7_row18_col24, #T_d29b7_row18_col60, #T_d29b7_row20_col60, #T_d29b7_row20_col83, #T_d29b7_row21_col41, #T_d29b7_row21_col42, #T_d29b7_row22_col60, #T_d29b7_row23_col4, #T_d29b7_row27_col83, #T_d29b7_row29_col27, #T_d29b7_row29_col60, #T_d29b7_row30_col27, #T_d29b7_row30_col66, #T_d29b7_row32_col60, #T_d29b7_row35_col86, #T_d29b7_row36_col60, #T_d29b7_row36_col61, #T_d29b7_row37_col27, #T_d29b7_row38_col42, #T_d29b7_row39_col42, #T_d29b7_row41_col86, #T_d29b7_row43_col35, #T_d29b7_row43_col41, #T_d29b7_row43_col42, #T_d29b7_row44_col23, #T_d29b7_row44_col54, #T_d29b7_row45_col39, #T_d29b7_row45_col57, #T_d29b7_row46_col75, #T_d29b7_row46_col76, #T_d29b7_row47_col86, #T_d29b7_row48_col57, #T_d29b7_row49_col42, #T_d29b7_row49_col53, #T_d29b7_row50_col57, #T_d29b7_row50_col88, #T_d29b7_row52_col24, #T_d29b7_row52_col60, #T_d29b7_row52_col69, #T_d29b7_row53_col44, #T_d29b7_row54_col46, #T_d29b7_row54_col61, #T_d29b7_row55_col27, #T_d29b7_row55_col60, #T_d29b7_row55_col61, #T_d29b7_row55_col76, #T_d29b7_row56_col60, #T_d29b7_row57_col4, #T_d29b7_row59_col73, #T_d29b7_row61_col83, #T_d29b7_row63_col60, #T_d29b7_row64_col60, #T_d29b7_row64_col66, #T_d29b7_row66_col4, #T_d29b7_row66_col61, #T_d29b7_row67_col39, #T_d29b7_row68_col52, #T_d29b7_row69_col86, #T_d29b7_row70_col27, #T_d29b7_row70_col60, #T_d29b7_row72_col2, #T_d29b7_row72_col24, #T_d29b7_row72_col45, #T_d29b7_row72_col68, #T_d29b7_row73_col42, #T_d29b7_row74_col18, #T_d29b7_row75_col46, #T_d29b7_row77_col4, #T_d29b7_row77_col35, #T_d29b7_row77_col41, #T_d29b7_row77_col42, #T_d29b7_row77_col54, #T_d29b7_row77_col76, #T_d29b7_row78_col23, #T_d29b7_row78_col39, #T_d29b7_row78_col77, #T_d29b7_row79_col22, #T_d29b7_row80_col54, #T_d29b7_row80_col60, #T_d29b7_row81_col73, #T_d29b7_row81_col86, #T_d29b7_row83_col61, #T_d29b7_row84_col26, #T_d29b7_row84_col54, #T_d29b7_row85_col55, #T_d29b7_row86_col50, #T_d29b7_row86_col58, #T_d29b7_row87_col63, #T_d29b7_row87_col67, #T_d29b7_row87_col80, #T_d29b7_row88_col50 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_d29b7_row0_col3, #T_d29b7_row1_col69, #T_d29b7_row2_col25, #T_d29b7_row2_col84, #T_d29b7_row3_col79, #T_d29b7_row6_col3, #T_d29b7_row7_col3, #T_d29b7_row12_col74, #T_d29b7_row14_col3, #T_d29b7_row15_col42, #T_d29b7_row15_col52, #T_d29b7_row16_col10, #T_d29b7_row18_col74, #T_d29b7_row19_col3, #T_d29b7_row19_col16, #T_d29b7_row22_col18, #T_d29b7_row22_col52, #T_d29b7_row25_col45, #T_d29b7_row27_col30, #T_d29b7_row27_col73, #T_d29b7_row28_col42, #T_d29b7_row32_col34, #T_d29b7_row34_col25, #T_d29b7_row35_col78, #T_d29b7_row37_col49, #T_d29b7_row38_col51, #T_d29b7_row39_col58, #T_d29b7_row41_col68, #T_d29b7_row42_col34, #T_d29b7_row42_col58, #T_d29b7_row43_col16, #T_d29b7_row45_col35, #T_d29b7_row46_col33, #T_d29b7_row49_col32, #T_d29b7_row50_col5, #T_d29b7_row54_col5, #T_d29b7_row55_col30, #T_d29b7_row55_col64, #T_d29b7_row55_col79, #T_d29b7_row57_col9, #T_d29b7_row57_col32, #T_d29b7_row59_col44, #T_d29b7_row61_col30, #T_d29b7_row62_col56, #T_d29b7_row65_col56, #T_d29b7_row67_col68, #T_d29b7_row68_col58, #T_d29b7_row71_col49, #T_d29b7_row72_col3, #T_d29b7_row73_col79, #T_d29b7_row74_col68, #T_d29b7_row75_col44, #T_d29b7_row75_col68, #T_d29b7_row77_col16, #T_d29b7_row77_col49, #T_d29b7_row78_col69, #T_d29b7_row80_col46, #T_d29b7_row85_col75, #T_d29b7_row87_col31 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_d29b7_row0_col4, #T_d29b7_row0_col69, #T_d29b7_row0_col76, #T_d29b7_row2_col56, #T_d29b7_row3_col37, #T_d29b7_row4_col26, #T_d29b7_row5_col26, #T_d29b7_row6_col4, #T_d29b7_row6_col69, #T_d29

# %%
import dataframe_image as dfi

corlist = ['rko_start_months', 'cnt_days_deb_e_oper_1m', 'cnt_cred_e_oper_1m', 'cnt_days_cred_e_oper_1m', 'cnt_days_deb_f_oper_1m', 'cnt_days_deb_h_oper_1m', 'cnt_days_cred_h_oper_1m', 'sum_deb_e_oper_3m', 'cnt_deb_e_oper_3m', 'cnt_days_deb_e_oper_3m', 'sum_cred_e_oper_3m', 'cnt_days_cred_e_oper_3m', 'cnt_days_deb_f_oper_3m', 'cnt_deb_h_oper_3m', 'cnt_days_deb_h_oper_3m', 'cnt_days_cred_h_oper_3m']

corr = train_data[corlist].corr().round(3)
df_styled = corr.style.background_gradient(cmap='coolwarm')
df_styled
# Out:
# <style type="text/css">
# #T_83916_row0_col0, #T_83916_row1_col1, #T_83916_row2_col2, #T_83916_row3_col3, #T_83916_row4_col4, #T_83916_row5_col5, #T_83916_row6_col6, #T_83916_row7_col7, #T_83916_row8_col8, #T_83916_row9_col9, #T_83916_row10_col10, #T_83916_row11_col11, #T_83916_row12_col12, #T_83916_row13_col13, #T_83916_row14_col14, #T_83916_row15_col15 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_83916_row0_col1, #T_83916_row0_col2, #T_83916_row0_col3, #T_83916_row0_col4, #T_83916_row0_col6, #T_83916_row0_col8, #T_83916_row0_col9, #T_83916_row0_col11, #T_83916_row0_col12, #T_83916_row3_col0, #T_83916_row4_col5, #T_83916_row4_col7, #T_83916_row4_col10, #T_83916_row4_col13, #T_83916_row4_col14, #T_83916_row4_col15, #T_83916_row12_col5, #T_83916_row12_col6, #T_83916_row13_col12 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_83916_row0_col5, #T_83916_row2_col0 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_83916_row0_col7, #T_83916_row5_col12, #T_83916_row12_col10, #T_83916_row12_col13, #T_83916_row12_col14 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_83916_row0_col10 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_83916_row0_col13, #T_83916_row3_col6, #T_83916_row11_col15 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_83916_row0_col14, #T_83916_row8_col0 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_83916_row0_col15, #T_83916_row11_col0, #T_83916_row14_col4 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_83916_row1_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_83916_row1_col2 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_83916_row1_col3 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_83916_row1_col4 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_83916_row1_col5 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_83916_row1_col6, #T_83916_row1_col15, #T_83916_row11_col7, #T_83916_row11_col10 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_83916_row1_col7, #T_83916_row1_col10, #T_83916_row7_col3, #T_83916_row8_col12, #T_83916_row9_col10 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_83916_row1_col8, #T_83916_row5_col7, #T_83916_row5_col10, #T_83916_row8_col9 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_83916_row1_col9 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_83916_row1_col11 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_83916_row1_col12 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_83916_row1_col13, #T_83916_row2_col13, #T_83916_row13_col3, #T_83916_row15_col10 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_83916_row1_col14, #T_83916_row12_col9 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_83916_row2_col1, #T_83916_row9_col12, #T_83916_row12_col1, #T_83916_row14_col1 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_83916_row2_col3 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_83916_row2_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_83916_row2_col5, #T_83916_row3_col14, #T_83916_row6_col14 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_83916_row2_col6, #T_83916_row2_col15, #T_83916_row15_col11 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_83916_row2_col7, #T_83916_row4_col8 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_83916_row2_col8, #T_83916_row5_col2 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_83916_row2_col9, #T_83916_row3_col5, #T_83916_row6_col5 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_83916_row2_col10 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_83916_row2_col11, #T_83916_row7_col13 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_83916_row2_col12 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_83916_row2_col14, #T_83916_row4_col3, #T_83916_row11_col8, #T_83916_row12_col3, #T_83916_row14_col8 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_83916_row3_col1 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_83916_row3_col2 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_83916_row3_col4, #T_83916_row6_col7, #T_83916_row11_col13 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_83916_row3_col7, #T_83916_row6_col0 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_83916_row3_col8, #T_83916_row5_col6, #T_83916_row7_col8, #T_83916_row10_col15, #T_83916_row13_col9 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_83916_row3_col9 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_83916_row3_col10, #T_83916_row4_col2, #T_83916_row12_col2, #T_83916_row13_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_83916_row3_col11 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_83916_row3_col12, #T_83916_row8_col10, #T_83916_row10_col9 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_83916_row3_col13, #T_83916_row4_col11 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_83916_row3_col15, #T_83916_row6_col12, #T_83916_row7_col4, #T_83916_row10_col4 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_83916_row4_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_83916_row4_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_83916_row4_col6 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_83916_row4_col9, #T_83916_row8_col11 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_83916_row4_col12 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_83916_row5_col0, #T_83916_row8_col15, #T_83916_row9_col6, #T_83916_row10_col0 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_83916_row5_col1 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_83916_row5_col3, #T_83916_row9_col14 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_83916_row5_col4 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_83916_row5_col8, #T_83916_row8_col5, #T_83916_row14_col15 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_83916_row5_col9 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_83916_row5_col11, #T_83916_row15_col13, #T_83916_row15_col14 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_83916_row5_col13 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_83916_row5_col14, #T_83916_row14_col5 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_83916_row5_col15, #T_83916_row12_col11, #T_83916_row13_col11 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_83916_row6_col1, #T_83916_row7_col11, #T_83916_row10_col11 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_83916_row6_col2, #T_83916_row7_col9, #T_83916_row10_col6, #T_83916_row15_col2 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_83916_row6_col3 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_83916_row6_col4, #T_83916_row15_col4 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_83916_row6_col8 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_83916_row6_col9, #T_83916_row6_col11 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_83916_row6_col10 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_83916_row6_col13, #T_83916_row11_col5 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_83916_row6_col15, #T_83916_row12_col4, #T_83916_row15_col6 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_83916_row7_col0 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_83916_row7_col1, #T_83916_row10_col1 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_83916_row7_col2 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_83916_row7_col5, #T_83916_row7_col14, #T_83916_row10_col5 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_83916_row7_col6, #T_83916_row8_col7, #T_83916_row10_col2, #T_83916_row11_col4, #T_83916_row13_col6 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_83916_row7_col10, #T_83916_row10_col7 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_83916_row7_col12 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_83916_row7_col15, #T_83916_row10_col8, #T_83916_row13_col15 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_83916_row8_col1 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_83916_row8_col2, #T_83916_row8

# %%
train_data.drop(["id", "target_1","target_2"], axis=1, inplace=True)

# %%
y = train_data.total_target
x = train_data.drop("total_target", axis=1)

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y,
                                                  random_state=42)

# %%
model = LGBMClassifier(verbosity=-1, random_state = 42,  n_estimators=100, max_depth = 8, num_leaves = 70, learning_rate = 0.05, bootstrap = False, extra_trees = False, xgboost_dart_mode = True, feature_fraction = 0.9, reg_alpha = 0.9, reg_lambda = 0.9) #0.87569
model.fit(x_train, y_train)
# Out:
# LGBMClassifier(bootstrap=False, extra_trees=False, feature_fraction=0.9,
#                learning_rate=0.05, max_depth=8, num_leaves=70, random_state=42,
#                reg_alpha=0.9, reg_lambda=0.9, verbosity=-1,
#                xgboost_dart_mode=True)

# %%
y_pred = model.predict_proba(x_val)[:, 1]
roc_auc_score(y_val, y_pred)
# Out:
# 0.8709212109315453

# %%
test_score = model.predict_proba(test_data.drop("id", axis=1))[:, 1]
sample_submission_df = pd.read_csv("../sample_submission.csv")
sample_submission_df.head()
sample_submission_df["score"] = test_score
sample_submission_df.head()
sample_submission_df.to_csv("../result.csv", index=False)

# %%
df = pd.read_csv("../result.csv")
df
# Out:
#            id     score
# 0      300000  0.442694
# 1      300001  0.477039
# 2      300002  0.008593
# 3      300003  0.008305
# 4      300004  0.014162
# ...       ...       ...
# 99995  399995  0.014758
# 99996  399996  0.011416
# 99997  399997  0.030255
# 99998  399998  0.028378
# 99999  399999  0.014434
#
# [100000 rows x 2 columns]

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
import itertools

font = {'size' : 15}

plt.rc('font', **font)

cnf_matrix = confusion_matrix(y, model.predict(x))
plt.figure(figsize=(10, 8))
plot_confusion_matrix(cnf_matrix, classes=['Положительное', 'Отрицательное'],
                      title='Матрица ошибок')
plt.show()
# Out:
# Confusion matrix, without normalization
# [[247997   1709]
#  [ 16699   3864]]

# %%
report = classification_report(y, model.predict(x), target_names=['Положительное', 'Отрицательное'])
print(report)
# Out:
#                precision    recall  f1-score   support
#
# Положительное       0.94      0.99      0.96    249706
# Отрицательное       0.69      0.19      0.30     20563
#
#      accuracy                           0.93    270269
#     macro avg       0.82      0.59      0.63    270269
#  weighted avg       0.92      0.93      0.91    270269

# %%
sns.set(font_scale=1.5)
sns.set_color_codes("muted")

plt.figure(figsize=(10, 8))
fpr, tpr, thresholds = roc_curve(y, model.predict_proba(x)[:,1], pos_label=1)
lw = 2
plt.plot(fpr, tpr, lw=lw, label='ROC curve ')
plt.plot([0, 1], [0, 1])
plt.xlim([0.0, 1.0])
plt.xticks([i/10 for i in range(1,11)])
plt.ylim([0.0, 1.05])
plt.yticks([i/10 for i in range(1,11)])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve')
plt.savefig("ROC.png")
plt.show()

# %%
y_prob = model.predict_proba(x)[:, 1]
roc_auc_score(y, y_prob)
# Out:
# 0.8971895426967939
